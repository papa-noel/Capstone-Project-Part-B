# %%
import folium
import math

# %%
# lat & longs of center of captured images
locations = {
    'Noel': [
    (32.8353107,-117.1939721), 
    (32.8353005,-117.1921541),
    (32.835252,-117.1905991),
    (32.8371028,-117.1880858),
    (32.8385846,-117.1869454), #5
    (32.839643,-117.1870219),
    (32.8264453,-117.1832565),
    (32.7844412,-117.1668956),
    (32.7862222,-117.1661486),
    (32.7937215,-117.1754918), #10
    (32.7952621,-117.1754151),
    (32.7950809,-117.1676967),
    (32.7806203,-117.2044161),
    (32.7768463,-117.2016394),
    (32.7760929,-117.1929139), #15
    (32.776029,-117.1959058),
    (32.7667972,-117.1910794),
    (32.7919718,-117.0908485),
    (32.7913077,-117.0900226),
    (32.7965164,-117.0835183), #20
    (32.7974655,-117.0695503), 
    (32.7956924,-117.0663954),
    (32.8051316,-117.0219805),
    (32.8063108,-117.0209906),
    (32.8052109,-117.0193553),
    (32.8062484,-117.0119538) #26
],

    'Josh': [],

    'Alex': [],

    'Lauren': []

}

# %%
# Calculate the boundaries of the tile
def calculate_bounds(lat, lon, zoom = 19, size = "640x640", scale = 2):
    """
    Calculate the boundaries of a square tile in geographical coordinates.

    """
    parallel_multiplier = math.cos(lat * math.pi / 180)
    degrees_per_pixel_x = 360 / math.pow(2, zoom + 8)
    degrees_per_pixel_y = 360 / math.pow(2, zoom + 8) * parallel_multiplier

    half_tile_size = size / scale

    delta_lat = degrees_per_pixel_y * half_tile_size
    delta_lon = degrees_per_pixel_x * half_tile_size

    lat_min = lat - delta_lat
    lat_max = lat + delta_lat
    lon_min = lon - delta_lon
    lon_max = lon + delta_lon

    return ((lat_min, lon_min), (lat_max, lon_max))

# %%
# Creates a map centered around San Diego
map_sd = folium.Map(location=[32.7157, -117.1611], zoom_start=11)

# For each location, calculate the boundary and add a rectangle
for name in locations:

    if name == 'Noel':
        color = 'blue'
    elif name == 'Alex':
        color = 'red'
    elif name == 'Lauren':
        color = 'yellow'
    else:
        color = 'green'

    for lat, long in locations[name]:
        
        bounds = calculate_bounds(lat, long, zoom=19, size=640)
        
        # Create a rectangle and add to the map
        folium.Rectangle(
            bounds=bounds,
            color=color,
            fill=True,
            fill_opacity=0.3,
            popup=folium.Popup(str(lat) + ", " + str(long))
        ).add_to(map_sd)

# Display the map in a notebook or export
#map_sd.save('san_diego_map.html')

# %%
map_sd
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f68ac6a8ad60a71265f5890cb1adcc02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f68ac6a8ad60a71265f5890cb1adcc02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f68ac6a8ad60a71265f5890cb1adcc02 = L.map(
#                 &quot;map_f68ac6a8ad60a71265f5890cb1adcc02&quot;,
#                 {
#                     center: [32.7157, -117.1611],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_100e40e80b1c86d382b6299bf909e459 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_100e40e80b1c86d382b6299bf909e459.addTo(map_f68ac6a8ad60a71265f5890cb1adcc02);
#
#
#             var rectangle_8e7668d70b437f4586f121420a032c44 = L.rectangle(
#                 [[32.83458952257836, -117.19483040688476], [32.83603187742164, -117.19311379311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f68ac6a8ad60a71265f5890cb1adcc02);
#
#
#         var popup_cd23cecef404ac2333dab4a8e0cded07 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94e2b91ae71f7726327e49aa93aba55a = $(`&lt;div id=&quot;html_94e2b91ae71f7726327e49aa93aba55a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353107, -117.1939721&lt;/div&gt;`)[0];
#                 popup_cd23cecef404ac2333dab4a8e0cded07.setContent(html_94e2b91ae71f7726327e49aa93aba55a);
#
#
#
#         rectangle_8e7668d70b437f4586f121420a032c44.bindPopup(popup_cd23cecef404ac2333dab4a8e0cded07)
#         ;
#
#
#
#
#             var rectangle_e361beb64c2bc41a5ab5159438acea94 = L.rectangle(
#                 [[32.834579322495514, -117.19301240688476], [32.83602167750449, -117.19129579311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f68ac6a8ad60a71265f5890cb1adcc02);
#
#
#         var popup_8e23312b70b876344e73431e9f55a274 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9897ea56e4def5a441733cbe473458a7 = $(`&lt;div id=&quot;html_9897ea56e4def5a441733cbe473458a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.8353005, -117.1921541&lt;/div&gt;`)[0];
#                 popup_8e23312b70b876344e73431e9f55a274.setContent(html_9897ea56e4def5a441733cbe473458a7);
#
#
#
#         rectangle_e361beb64c2bc41a5ab5159438acea94.bindPopup(popup_8e23312b70b876344e73431e9f55a274)
#         ;
#
#
#
#
#             var rectangle_ff641ffa9ca390a6938edcb8edb642cd = L.rectangle(
#                 [[32.83453082210156, -117.19145740688477], [32.83597317789843, -117.18974079311523]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f68ac6a8ad60a71265f5890cb1adcc02);
#
#
#         var popup_3cd86f1b637c8c1fc9a071e6ce37f011 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9dcdbe907c90655282438b428d588cf9 = $(`&lt;div id=&quot;html_9dcdbe907c90655282438b428d588cf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32.835252, -117.1905991&lt;/div&gt;`)[0];
#                 popup_3cd86f1b637c8c1fc9a071e6ce37f011.setContent(html_9dcdbe907c90655282438b428d588cf9);
#
#
#
#         rectangle_ff641ffa9ca390a6938edcb8edb642cd.bindPopup(popup_3cd86f1b637c8c1fc9a071e6ce37f011)
#         ;
#
#
#
#
#             var rectangle_9cfe1e02dd1870e01228f107f3f42d57 = L.rectangle(
